# %%
import pandas as pd

# %%
df_EXTRACT = pd.read_csv('Master_Pixstory_EXTRACT_Dataset.tsv', delimiter="\t")
df_ANALYSIS = pd.read_csv('Master_Pixstory_ANALYSIS_Dataset.tsv', delimiter="\t")
print(df_EXTRACT.columns)
print(df_ANALYSIS.columns)
# get number of rows
num_rows = df_EXTRACT.shape[0]
print("EXTRACT Number of rows:", num_rows)
# get number of rows
num_rows = df_ANALYSIS.shape[0]
print("ANALYSIS Number of rows:", num_rows)
# Out:
# /var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_59750/4165281863.py:2: DtypeWarning: Columns (0,2,5,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ANALYSIS = pd.read_csv('Master_Pixstory_ANALYSIS_Dataset.tsv', delimiter="\t")
# Index(['Dataset Index', 'Story Primary ID', 'Story ID', 'User Primary ID',
#        'User ID', 'Gender', 'Age', 'MediaTitle', 'Narrative',
#        'Account Created Date', 'Date (No Timestamp)', 'Interest',
#        'Narrative TikaDetect', 'Title TikaDetect', 'Narrative LangDetect',
#        'Title LangDetect', 'Translated Narrative', 'Translated Title',
#        'GeoTopic Name', 'GeoTopic Latitude', 'GeoTopic Longitude',
#        'caption_generation', 'object_recognition', 'toxicity',
#        'severe_toxicity', 'obscene', 'identity_attack', 'insult', 'threat',
#        'sexual_explicit'],
#       dtype='object')
# Index(['Story Primary ID', 'Story ID', 'User Primary ID', 'User ID', 'Gender',
# ...

# %%
# read TSV file into DataFrame
df = pd.read_csv('../ARCHIVE/DSCI550Assignment3_DRAFT_DATASET.csv')

# %%
df
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 0                121169  STY1659426957              103  USR1606807023
# 1                127727  STY1660634861              103  USR1606807023
# 2                123665  STY1660027898              103  USR1606807023
# 3                130517  STY1661151635              103  USR1606807023
# 4                125466  STY1660372361              109  USR1606851217
# ...                 ...            ...              ...            ...
# 95261            140260  STY1662668322            40236  USR1653908660
# 95262            140129  STY1662655852            90244  USR1662655326
# 95263            143102  STY1663172144            95717  USR1663171000
# 95264            146762  STY1663735317            99782  USR1663587363
# 95265            146118  STY1663607824           100078  USR1663607515
#
#        Gender  Age                                             Title  \
# ...

# %%
# get number of rows
num_rows = df.shape[0]
print("Number of rows:", num_rows)
# Out:
# Number of rows: 95266

# %%
df = df.drop('MediaTitle', axis=1)

# %%
print(df.columns)
# Out:
# Index(['Story Primary ID', 'Story ID', 'User Primary ID', 'User ID', 'Gender',
#        'Age', 'Title', 'Narrative', 'Media', 'Account Created Date',
#        'Date (No Timestamp)', 'Interest', 'Sports Events',
#        'Associated Film Festivals', 'Hate Speech Flag', 'Hate Speech Detected',
#        'Year_Quarter', 'Snapchat_Quarterly_Revenue', 'Snapchat_Quarterly_DAUs',
#        'Snapchat_Closing_Stock_Price', 'New COVID Cases', 'New Deaths',
#        'New Vaccinations', 'YouTube Trending Video Title',
#        'YouTube Trending Video Channel', 'YouTube Trending Video Category',
#        'YouTube Trending Video Views', 'YouTube Trending Video Likes',
#        'is_sarcastic', 'Dataset Index', 'Narrative TikaDetect',
#        'Title TikaDetect', 'Narrative LangDetect', 'Title LangDetect',
#        'Translated Narrative', 'Translated Title', 'GeoTopic Name',
#        'GeoTopic Latitude', 'GeoTopic Longitude', 'caption_generation',
# ...

# %%
newColOrder = ['Dataset Index', 'Story Primary ID', 'Story ID', 'User Primary ID', 'User ID', 'Gender',
       'Age', 'Title', 'Narrative', 'Media', 'Account Created Date',
       'Date (No Timestamp)', 'Interest', 'Sports Events',
       'Associated Film Festivals', 'Hate Speech Flag', 'Hate Speech Detected',
       'Year_Quarter', 'Snapchat_Quarterly_Revenue', 'Snapchat_Quarterly_DAUs',
       'Snapchat_Closing_Stock_Price', 'New COVID Cases', 'New Deaths',
       'New Vaccinations', 'YouTube Trending Video Title',
       'YouTube Trending Video Channel', 'YouTube Trending Video Category',
       'YouTube Trending Video Views', 'YouTube Trending Video Likes',
       'is_sarcastic', 'Narrative TikaDetect',
       'Title TikaDetect', 'Narrative LangDetect', 'Title LangDetect',
       'Translated Narrative', 'Translated Title', 'GeoTopic Name',
       'GeoTopic Latitude', 'GeoTopic Longitude', 'caption_generation',
       'object_recognition', 'toxicity', 'severe_toxicity', 'obscene',
       'identity_attack', 'insult', 'threat', 'sexual_explicit']

# %%
# move columns around
df = df[newColOrder]

# %%
df = df.drop('Dataset Index', axis=1)

# %%
df
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 0                121169  STY1659426957              103  USR1606807023
# 1                127727  STY1660634861              103  USR1606807023
# 2                123665  STY1660027898              103  USR1606807023
# 3                130517  STY1661151635              103  USR1606807023
# 4                125466  STY1660372361              109  USR1606851217
# ...                 ...            ...              ...            ...
# 95261            140260  STY1662668322            40236  USR1653908660
# 95262            140129  STY1662655852            90244  USR1662655326
# 95263            143102  STY1663172144            95717  USR1663171000
# 95264            146762  STY1663735317            99782  USR1663587363
# 95265            146118  STY1663607824           100078  USR1663607515
#
#        Gender  Age                                             Title  \
# ...

# %%
# rename columns
# df = df.rename(columns={'col1': 'new_col1', 'col2': 'new_col2'}) # replace col1, col2 with the actual column names

# %%
# typecast a column to datetime objects
df['Account Created Date'] = pd.to_datetime(df['Account Created Date'])

# sort by date in ascending order
df = df.sort_values('Account Created Date', ascending=True)

# %%
df
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 0                121169  STY1659426957              103  USR1606807023
# 1                127727  STY1660634861              103  USR1606807023
# 2                123665  STY1660027898              103  USR1606807023
# 3                130517  STY1661151635              103  USR1606807023
# 4                125466  STY1660372361              109  USR1606851217
# ...                 ...            ...              ...            ...
# 95252            125345  STY1660325638            71673  USR1660325486
# 95253            125351  STY1660326276            71698  USR1660326026
# 95254            125355  STY1660326971            71697  USR1660326022
# 95255            125354  STY1660326403            71708  USR1660326251
# 59849            147880  STY1663995924            36808  USR1652654597
#
#        Gender  Age                                             Title  \
# ...

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# get number of rows
num_rows = df.shape[0]

print("Number of rows:", num_rows)
# Out:
# Number of rows: 95009

# %%
df = df.dropna(subset=['Account Created Date'])

# %%
# reset index and create new column
df = df.reset_index(drop=False)
df = df.rename(columns={'index': 'Dataset Index1'})
df = df.reset_index(drop=False)
df = df.rename(columns={'index': 'Dataset Index2'})

# %%
df = df.drop('Dataset Index1', axis=1)
df = df.rename(columns={'Dataset Index2': 'Dataset Index'}) # replace old_col_name and new_col_name with the actual column names

# %%
df = df.rename(columns={'Dataset Index2': 'Dataset Index'}) # replace old_col_name and new_col_name with the actual column names

df
# Out:
#        Dataset Index  Story Primary ID       Story ID  User Primary ID  \
# 0                  0            121169  STY1659426957              103
# 1                  1            127727  STY1660634861              103
# 2                  2            123665  STY1660027898              103
# 3                  3            130517  STY1661151635              103
# 4                  4            125466  STY1660372361              109
# ...              ...               ...            ...              ...
# 95003          95003            125349  STY1660325841            71665
# 95004          95004            125345  STY1660325638            71673
# 95005          95005            125351  STY1660326276            71698
# 95006          95006            125355  STY1660326971            71697
# 95007          95007            125354  STY1660326403            71708
#
#              User ID  Gender  Age  \
# 0      USR1606807023  female   34
# 1      USR1606807023  female   34
# ...

# %%
# display a sample of certain columns
sample_cols = ['Title', 'Narrative', 'Account Created Date',
       'Date (No Timestamp)', 'Interest', 'Sports Events',
       'Associated Film Festivals', 'Narrative TikaDetect',
       'Title TikaDetect', 'Narrative LangDetect', 'Title LangDetect',
       'Translated Narrative', 'Translated Title', 'GeoTopic Name',
       'GeoTopic Latitude', 'GeoTopic Longitude']
sample_size = 20
sample_df = df[sample_cols]
# sample_df = df[sample_cols].sample(n=sample_size, random_state=42)

# %%
sample_df
# Out:
#                                                   Title  \
# 0                         Trend of the Year: Barbiecore
# 1                                Abomination of the day
# 2                             Shameful headline in 2022
# 3      Woman lawyer arrested for abusing security guard
# 4                  What is the Inflation Reduction Act?
# ...                                                 ...
# 95003                                      COLLEGE LIFE
# 95004                          The one with the bestie😍
# 95005                              A tale of friendship
# 95006                                           College
# 95007                       The mandatory mirror selfie
#
#                                                Narrative Account Created Date  \
# 0      The colour of the year is here, and it's *drum...  2020-01-12 12:47:00
# 1      We Indians do love to bastardise our foods- Ch...  2020-01-12 12:47:00
# ...

# %%
break
# Out:
#   File "/var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_59750/668683560.py", line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
# save DataFrame to CSV file
df.to_csv('Master_Pixstory_Dataset_EXTRACT_ANALYSIS.csv', index=False)
